# %%
import pandas as pd
import numpy as np
import os
import sys
import random
# librosa is a Python library for analyzing audio and music. It can be used to extract the data from the audio files we will see it later.
import librosa
import librosa.display
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="whitegrid")
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.model_selection import train_test_split
# to play the audio files
from IPython.display import Audio
from tensorflow import keras
from tensorflow.keras import layers
from keras.callbacks import ReduceLROnPlateau, EarlyStopping
from keras.models import Sequential, model_from_json
from keras.layers import Dense, Conv1D, MaxPooling1D, Flatten, Dropout, BatchNormalization, LSTM, Bidirectional
#from keras.utils import np_utils
#from tensorflow.keras.utils import to_categorical
from keras.callbacks import ModelCheckpoint
import warnings
if not sys.warnoptions:
    warnings.simplefilter("ignore")
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
Features = pd.read_csv('/content/New_Features.csv')
Features
# Out:
#                 0           1         2          3          4          5  \
# 0     -667.117126   79.265198  0.214563  14.969451   8.738843   1.614774
# 1     -615.445834   66.686741  2.038200  12.995424   7.055977   0.668474
# 2     -687.362793   75.290352 -1.210264  14.314221   8.129561   0.945795
# 3     -667.303345   79.338615  0.108453  15.009537   8.758369   1.515849
# 4     -693.085693   76.648788 -2.235734  15.661802   6.219852   0.362040
# ...           ...         ...       ...        ...        ...        ...
# 85129 -535.529419  147.678757  4.125548  41.282303  17.964502 -11.436426
# 85130 -502.414154  140.167130  8.310973  39.715385  19.929995 -10.111897
# 85131 -529.508423  149.243805  1.640323  43.740402  12.895799 -14.372314
# 85132 -518.020935  149.392151  5.166693  41.144249  16.747551 -11.291152
# 85133 -518.020935  149.392151  5.166693  41.144249  16.747551 -11.291152
#
#                6          7          8          9  ...        49        50  \
# 0      -1.532764  -7.318048  -9.807106  -5.784626  ... -2.586592 -4.365417
# 1      -2.428976  -7.810624  -9.911508  -5.906373  ... -2.932330 -4.386004
# 2      -2.258029  -8.516194 -10.246474  -6.361144  ... -2.553753 -4.103726
# 3      -1.553606  -7.425676  -9.832697  -5.729956  ... -2.600850 -4.390324
# 4      -5.023983 -10.431814 -11.020267  -4.200710  ... -3.485274 -5.102743
# ...          ...        ...        ...        ...  ...       ...       ...
# 85129 -23.290176 -10.401311 -20.307558 -16.549686  ...  4.558703  5.847288
# 85130 -22.219362 -10.496548 -18.203625 -15.398740  ...  3.800341  4.825471
# 85131 -24.122408 -11.195657 -23.619652 -12.793048  ...  7.092883  6.771282
# 85132 -22.993483 -12.438994 -20.976929 -16.510225  ...  4.798247  5.194843
# 85133 -22.993483 -12.438994 -20.976929 -16.510225  ...  4.798247  5.194843
#
#              51        52        53        54        55        56        57  \
# 0     -3.526464 -3.893123 -1.308869 -1.534479  0.177820 -1.924504 -0.712043
# 1     -4.143258 -3.913866 -1.603605 -1.136018 -0.033799 -2.084259 -0.914395
# 2     -3.207460 -3.594904 -1.535071 -1.503656  0.118786 -1.881907 -0.801992
# 3     -3.556926 -3.911522 -1.313280 -1.559114  0.175842 -1.911970 -0.718179
# 4     -1.389806 -1.083113  0.435190 -1.434615 -0.911742 -1.479177  1.416159
# ...         ...       ...       ...       ...       ...       ...       ...
# 85129  5.931197  4.891540  7.800804  8.906653  7.175795  6.862854  7.903193
# 85130  5.327935  4.948666  7.120644  7.927286  6.670240  6.660429  7.354165
# 85131  6.040644  8.963752  9.710288  6.482085  6.156532  6.609173  4.485555
# 85132  5.292653  4.442547  7.593217  9.390950  7.236876  6.638849  8.072015
# 85133  5.292653  4.442547  7.593217  9.390950  7.236876  6.638849  8.072015
#
#              labels
# 0      male_neutral
# 1      male_neutral
# 2      male_neutral
# 3      male_neutral
# 4      male_neutral
# ...             ...
# 85129    male_happy
# 85130    male_happy
# 85131    male_happy
# 85132    male_happy
# 85133    male_happy
#
# [85134 rows x 59 columns]

# %%
X = Features.iloc[: ,:-1].values
Y = Features['labels'].values

# %%
from imblearn.over_sampling import SMOTE
from collections import Counter

sm = SMOTE(random_state=42)

X_res, y_res = sm.fit_resample(X, Y)
print("Original Data: ", Counter(Y))
print("After Over Sampling: ", Counter(y_res))
# Out:
# Original Data:  Counter({'female_disgust': 7672, 'female_fear': 7672, 'female_sad': 7672, 'female_happy': 7672, 'female_angry': 7672, 'female_neutral': 7392, 'male_neutral': 5873, 'male_sad': 5789, 'male_fear': 5789, 'male_happy': 5789, 'male_disgust': 5789, 'male_angry': 5789, 'female_surprise': 3472, 'male_surprise': 1092})
# After Over Sampling:  Counter({'male_neutral': 7672, 'male_sad': 7672, 'male_fear': 7672, 'male_happy': 7672, 'male_disgust': 7672, 'male_angry': 7672, 'male_surprise': 7672, 'female_surprise': 7672, 'female_neutral': 7672, 'female_disgust': 7672, 'female_fear': 7672, 'female_sad': 7672, 'female_happy': 7672, 'female_angry': 7672})

# %%
encoder = OneHotEncoder()
Y_res = encoder.fit_transform(np.array(Y).reshape(-1,1)).toarray()

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y_res,test_size = 0.2, random_state=42, shuffle=True)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((68107, 58), (68107, 14), (17027, 58), (17027, 14))

# %%
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((68107, 58), (68107, 14), (17027, 58), (17027, 14))

# %%
# making our data compatible to model.
x_train = np.expand_dims(x_train, axis=2)
x_test = np.expand_dims(x_test, axis=2)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((68107, 58, 1), (68107, 14), (17027, 58, 1), (17027, 14))

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from keras.callbacks import ReduceLROnPlateau, EarlyStopping
from keras.models import Sequential
from keras.layers import Dense, Conv1D, MaxPooling1D, Flatten, Dropout, BatchNormalization, LSTM, Bidirectional
#from keras.utils import np_utils, to_categorical
from keras.callbacks import ModelCheckpoint

# %%
model = Sequential()
model.add(layers.Conv1D(512, kernel_size=5, strides=1,
                        padding="same", activation="relu",
                        input_shape=(x_train.shape[1], 1)))
model.add(layers.BatchNormalization())
model.add(layers.MaxPool1D(pool_size=5, strides=2, padding="same"))

model.add(layers.Conv1D(256, kernel_size=5, strides=1,
                        padding="same", activation="relu"))
model.add(layers.BatchNormalization())
model.add(layers.MaxPool1D(pool_size=5, strides=2, padding="same"))

model.add(layers.Flatten())
model.add(layers.Dense(512, activation='relu'))
model.add(layers.BatchNormalization())
model.add(layers.Dense(14, activation="softmax"))

model.compile(optimizer='RMSprop', loss='categorical_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_18 (Conv1D)          (None, 58, 512)           3072
#
#  batch_normalization_24 (Ba  (None, 58, 512)           2048
#  tchNormalization)
#
#  max_pooling1d_18 (MaxPooli  (None, 29, 512)           0
#  ng1D)
#
#  conv1d_19 (Conv1D)          (None, 29, 256)           655616
#
#  batch_normalization_25 (Ba  (None, 29, 256)           1024
#  tchNormalization)
#
#  max_pooling1d_19 (MaxPooli  (None, 15, 256)           0
#  ng1D)
#
#  flatten_6 (Flatten)         (None, 3840)              0
#
#  dense_12 (Dense)            (None, 512)               1966592
#
#  batch_normalization_26 (Ba  (None, 512)               2048
#  tchNormalization)
#
#  dense_13 (Dense)            (None, 14)                7182
#
# =================================================================
# Total params: 2637582 (10.06 MB)
# Trainable params: 2635022 (10.05 MB)
# Non-trainable params: 2560 (10.00 KB)
# _________________________________________________________________

# %%
rlrp = ReduceLROnPlateau(monitor='val_accuracy',
                                            patience=3,
                                            verbose=1,
                                            factor=0.5,
                                            min_lr=0.00001)
earlystopping = EarlyStopping(monitor ="val_accuracy",
                              mode = 'auto', patience = 5,
                              restore_best_weights = True)

history=model.fit(x_train, y_train, batch_size=64, epochs=50, validation_data=(x_test, y_test), callbacks=[rlrp,earlystopping])
# Out:
# Epoch 1/50
# 1065/1065 [==============================] - 19s 15ms/step - loss: 1.2679 - accuracy: 0.5525 - val_loss: 1.1014 - val_accuracy: 0.5990 - lr: 0.0010
# Epoch 2/50
# 1065/1065 [==============================] - 14s 13ms/step - loss: 0.8147 - accuracy: 0.7065 - val_loss: 0.8835 - val_accuracy: 0.6924 - lr: 0.0010
# Epoch 3/50
# 1065/1065 [==============================] - 10s 10ms/step - loss: 0.5491 - accuracy: 0.8070 - val_loss: 0.6297 - val_accuracy: 0.7757 - lr: 0.0010
# Epoch 4/50
# 1065/1065 [==============================] - 10s 10ms/step - loss: 0.3821 - accuracy: 0.8680 - val_loss: 0.5353 - val_accuracy: 0.8198 - lr: 0.0010
# Epoch 5/50
# 1065/1065 [==============================] - 11s 10ms/step - loss: 0.2769 - accuracy: 0.9045 - val_loss: 0.4727 - val_accuracy: 0.8474 - lr: 0.0010
# Epoch 6/50
# 1065/1065 [==============================] - 11s 10ms/step - loss: 0.2124 - accuracy: 0.9279 - val_loss: 0.4778 - val_accuracy: 0.8437 - lr: 0.0010
# Epoch 7/50
# 1065/1065 [==============================] - 10s 10ms/step - loss: 0.1738 - accuracy: 0.9404 - val_loss: 0.4200 - val_accuracy: 0.8717 - lr: 0.0010
# Epoch 8/50
# 1065/1065 [==============================] - 10s 10ms/step - loss: 0.1456 - accuracy: 0.9499 - val_loss: 0.4268 - val_accuracy: 0.8723 - lr: 0.0010
# Epoch 9/50
# 1065/1065 [==============================] - 11s 10ms/step - loss: 0.1181 - accuracy: 0.9604 - val_loss: 0.4350 - val_accuracy: 0.8828 - lr: 0.0010
# Epoch 10/50
# 1065/1065 [==============================] - 10s 10ms/step - loss: 0.1010 - accuracy: 0.9657 - val_loss: 0.4959 - val_accuracy: 0.8825 - lr: 0.0010
# Epoch 11/50
# 1065/1065 [==============================] - 10s 10ms/step - loss: 0.0858 - accuracy: 0.9712 - val_loss: 0.4640 - val_accuracy: 0.8846 - lr: 0.0010
# Epoch 12/50
# 1065/1065 [==============================] - 12s 11ms/step - loss: 0.0759 - accuracy: 0.9744 - val_loss: 0.4543 - val_accuracy: 0.8879 - lr: 0.0010
# Epoch 13/50
# 1065/1065 [==============================] - 10s 10ms/step - loss: 0.0712 - accuracy: 0.9761 - val_loss: 0.4475 - val_accuracy: 0.8880 - lr: 0.0010
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 1065/1065 [==============================] - 10s 9ms/step - loss: 0.0026 - accuracy: 0.9992 - val_loss: 0.4591 - val_accuracy: 0.9182 - lr: 5.0000e-04
# Epoch 31/50
# 1065/1065 [==============================] - 10s 10ms/step - loss: 0.0016 - accuracy: 0.9995 - val_loss: 0.4592 - val_accuracy: 0.9207 - lr: 2.5000e-04
# Epoch 32/50
# 1065/1065 [==============================] - 11s 10ms/step - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.4614 - val_accuracy: 0.9204 - lr: 2.5000e-04
# Epoch 33/50
# 1065/1065 [==============================] - 10s 10ms/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.4625 - val_accuracy: 0.9207 - lr: 2.5000e-04
# Epoch 34/50
# 1065/1065 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 0.9997
# Epoch 34: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 1065/1065 [==============================] - 10s 10ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.4538 - val_accuracy: 0.9204 - lr: 2.5000e-04
# Epoch 35/50
# 1065/1065 [==============================] - 10s 9ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.4582 - val_accuracy: 0.9205 - lr: 1.2500e-04
# Epoch 36/50
# 1065/1065 [==============================] - 11s 10ms/step - loss: 9.8616e-04 - accuracy: 0.9997 - val_loss: 0.4624 - val_accuracy: 0.9197 - lr: 1.2500e-04

# %%
print("Accuracy of our model on test data : " , round(model.evaluate(x_test,y_test)[1]*100,2) , "%")

epochs = [i for i in range(36)]
fig , ax = plt.subplots(1,2)
train_acc = history.history['accuracy']
train_loss = history.history['loss']
test_acc = history.history['val_accuracy']
test_loss = history.history['val_loss']

fig.set_size_inches(20,6)
ax[0].plot(epochs , train_loss , label = 'Training Loss')
ax[0].plot(epochs , test_loss , label = 'Testing Loss')
ax[0].set_title('Training & Testing Loss')
ax[0].legend()
ax[0].set_xlabel("Epochs")

ax[1].plot(epochs , train_acc , label = 'Training Accuracy')
ax[1].plot(epochs , test_acc , label = 'Testing Accuracy')
ax[1].set_title('Training & Testing Accuracy')
ax[1].legend()
ax[1].set_xlabel("Epochs")
plt.show()
# Out:
# 533/533 [==============================] - 4s 7ms/step - loss: 0.4592 - accuracy: 0.9207
# Accuracy of our model on test data :  92.07 %

# %%
from tensorflow.keras import layers, Sequential

model = Sequential()
model.add(layers.Conv1D(512, kernel_size=5, strides=1,
                        padding="same", activation="relu",
                        input_shape=(x_train.shape[1], 1)))
model.add(layers.BatchNormalization())
model.add(layers.MaxPool1D(pool_size=5, strides=2, padding="same"))

model.add(layers.Conv1D(256, kernel_size=5, strides=1,
                        padding="same", activation="relu"))
model.add(layers.BatchNormalization())
model.add(layers.MaxPool1D(pool_size=5, strides=2, padding="same"))

model.add(layers.Conv1D(128, kernel_size=3, strides=1,
                        padding="same", activation="relu"))
model.add(layers.BatchNormalization())
model.add(layers.MaxPool1D(pool_size=3, strides=2, padding="same"))

model.add(layers.Flatten())
model.add(layers.Dense(512, activation='relu'))
model.add(layers.BatchNormalization())
model.add(layers.Dense(14, activation="softmax"))

model.compile(optimizer='RMSprop', loss='categorical_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_20 (Conv1D)          (None, 58, 512)           3072
#
#  batch_normalization_27 (Ba  (None, 58, 512)           2048
#  tchNormalization)
#
#  max_pooling1d_20 (MaxPooli  (None, 29, 512)           0
#  ng1D)
#
#  conv1d_21 (Conv1D)          (None, 29, 256)           655616
#
#  batch_normalization_28 (Ba  (None, 29, 256)           1024
#  tchNormalization)
#
#  max_pooling1d_21 (MaxPooli  (None, 15, 256)           0
#  ng1D)
#
#  conv1d_22 (Conv1D)          (None, 15, 128)           98432
#
#  batch_normalization_29 (Ba  (None, 15, 128)           512
#  tchNormalization)
#
#  max_pooling1d_22 (MaxPooli  (None, 8, 128)            0
#  ng1D)
#
#  flatten_7 (Flatten)         (None, 1024)              0
#
#  dense_14 (Dense)            (None, 512)               524800
#
#  batch_normalization_30 (Ba  (None, 512)               2048
#  tchNormalization)
#
#  dense_15 (Dense)            (None, 14)                7182
#
# =================================================================
# Total params: 1294734 (4.94 MB)
# Trainable params: 1291918 (4.93 MB)
# Non-trainable params: 2816 (11.00 KB)
# _________________________________________________________________

# %%
rlrp = ReduceLROnPlateau(monitor='val_accuracy',
                                            patience=3,
                                            verbose=1,
                                            factor=0.5,
                                            min_lr=0.00001)
earlystopping = EarlyStopping(monitor ="val_accuracy",
                              mode = 'auto', patience = 5,
                              restore_best_weights = True)

history=model.fit(x_train, y_train, batch_size=64, epochs=50, validation_data=(x_test, y_test), callbacks=[rlrp,earlystopping])
# Out:
# Epoch 1/50
# 1065/1065 [==============================] - 14s 11ms/step - loss: 1.2932 - accuracy: 0.5415 - val_loss: 1.1580 - val_accuracy: 0.5860 - lr: 0.0010
# Epoch 2/50
# 1065/1065 [==============================] - 11s 10ms/step - loss: 0.8833 - accuracy: 0.6805 - val_loss: 1.0152 - val_accuracy: 0.6470 - lr: 0.0010
# Epoch 3/50
# 1065/1065 [==============================] - 11s 11ms/step - loss: 0.6409 - accuracy: 0.7709 - val_loss: 0.7517 - val_accuracy: 0.7322 - lr: 0.0010
# Epoch 4/50
# 1065/1065 [==============================] - 12s 11ms/step - loss: 0.4708 - accuracy: 0.8348 - val_loss: 0.7076 - val_accuracy: 0.7616 - lr: 0.0010
# Epoch 5/50
# 1065/1065 [==============================] - 11s 11ms/step - loss: 0.3618 - accuracy: 0.8733 - val_loss: 0.5508 - val_accuracy: 0.8165 - lr: 0.0010
# Epoch 6/50
# 1065/1065 [==============================] - 12s 11ms/step - loss: 0.2904 - accuracy: 0.8997 - val_loss: 0.4936 - val_accuracy: 0.8432 - lr: 0.0010
# Epoch 7/50
# 1065/1065 [==============================] - 11s 11ms/step - loss: 0.2391 - accuracy: 0.9181 - val_loss: 0.4720 - val_accuracy: 0.8565 - lr: 0.0010
# Epoch 8/50
# 1065/1065 [==============================] - 12s 11ms/step - loss: 0.2032 - accuracy: 0.9287 - val_loss: 0.4869 - val_accuracy: 0.8578 - lr: 0.0010
# Epoch 9/50
# 1065/1065 [==============================] - 12s 11ms/step - loss: 0.1743 - accuracy: 0.9401 - val_loss: 0.5206 - val_accuracy: 0.8512 - lr: 0.0010
# Epoch 10/50
# 1065/1065 [==============================] - 12s 11ms/step - loss: 0.1497 - accuracy: 0.9485 - val_loss: 0.4750 - val_accuracy: 0.8721 - lr: 0.0010
# Epoch 11/50
# 1065/1065 [==============================] - 12s 11ms/step - loss: 0.1350 - accuracy: 0.9540 - val_loss: 0.4554 - val_accuracy: 0.8762 - lr: 0.0010
# Epoch 12/50
# 1065/1065 [==============================] - 12s 11ms/step - loss: 0.1230 - accuracy: 0.9571 - val_loss: 0.4941 - val_accuracy: 0.8740 - lr: 0.0010
]
fig , ax = plt.subplots(1,2)
train_acc = history.history['accuracy']
train_loss = history.history['loss']
test_acc = history.history['val_accuracy']
test_loss = history.history['val_loss']

fig.set_size_inches(20,6)
ax[0].plot(epochs , train_loss , label = 'Training Loss')
ax[0].plot(epochs , test_loss , label = 'Testing Loss')
ax[0].set_title('Training & Testing Loss')
ax[0].legend()
ax[0].set_xlabel("Epochs")

ax[1].plot(epochs , train_acc , label = 'Training Accuracy')
ax[1].plot(epochs , test_acc , label = 'Testing Accuracy')
ax[1].set_title('Training & Testing Accuracy')
ax[1].legend()
ax[1].set_xlabel("Epochs")
plt.show()
# Out:
# 533/533 [==============================] - 3s 6ms/step - loss: 0.4541 - accuracy: 0.9229
# Accuracy of our model on test data :  92.29 %

# %%
from tensorflow.keras import layers, Sequential

model = Sequential()
model.add(layers.Conv1D(512, kernel_size=5, strides=1,
                        padding="same", activation="relu",
                        input_shape=(x_train.shape[1], 1)))
model.add(layers.BatchNormalization())
model.add(layers.MaxPool1D(pool_size=5, strides=2, padding="same"))

model.add(layers.Conv1D(512, kernel_size=5, strides=1,
                        padding="same", activation="relu"))
model.add(layers.BatchNormalization())
model.add(layers.MaxPool1D(pool_size=5, strides=2, padding="same"))

model.add(layers.Conv1D(256, kernel_size=5, strides=1,
                        padding="same", activation="relu"))
model.add(layers.BatchNormalization())
model.add(layers.MaxPool1D(pool_size=5, strides=2, padding="same"))

model.add(layers.Conv1D(128, kernel_size=3, strides=1,
                        padding="same", activation="relu"))
model.add(layers.BatchNormalization())
model.add(layers.MaxPool1D(pool_size=3, strides=2, padding="same"))

model.add(layers.Flatten())
model.add(layers.Dense(512, activation='relu'))
model.add(layers.BatchNormalization())
model.add(layers.Dense(14, activation="softmax"))

model.compile(optimizer='RMSprop', loss='categorical_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_23 (Conv1D)          (None, 58, 512)           3072
#
#  batch_normalization_31 (Ba  (None, 58, 512)           2048
#  tchNormalization)
#
#  max_pooling1d_23 (MaxPooli  (None, 29, 512)           0
#  ng1D)
#
#  conv1d_24 (Conv1D)          (None, 29, 512)           1311232
#
#  batch_normalization_32 (Ba  (None, 29, 512)           2048
#  tchNormalization)
#
#  max_pooling1d_24 (MaxPooli  (None, 15, 512)           0
#  ng1D)
#
#  conv1d_25 (Conv1D)          (None, 15, 256)           655616
#
#  batch_normalization_33 (Ba  (None, 15, 256)           1024
#  tchNormalization)
#
#  max_pooling1d_25 (MaxPooli  (None, 8, 256)            0
#  ng1D)
#
#  conv1d_26 (Conv1D)          (None, 8, 128)            98432
#
#  batch_normalization_34 (Ba  (None, 8, 128)            512
#  tchNormalization)
#
#  max_pooling1d_26 (MaxPooli  (None, 4, 128)            0
#  ng1D)
#
#  flatten_8 (Flatten)         (None, 512)               0
#
#  dense_16 (Dense)            (None, 512)               262656
#
#  batch_normalization_35 (Ba  (None, 512)               2048
#  tchNormalization)
#
#  dense_17 (Dense)            (None, 14)                7182
#
# =================================================================
# Total params: 2345870 (8.95 MB)
# Trainable params: 2342030 (8.93 MB)
# Non-trainable params: 3840 (15.00 KB)
# _________________________________________________________________

# %%
rlrp = ReduceLROnPlateau(monitor='val_accuracy',
                                            patience=3,
                                            verbose=1,
                                            factor=0.5,
                                            min_lr=0.00001)
earlystopping = EarlyStopping(monitor ="val_accuracy",
                              mode = 'auto', patience = 5,
                              restore_best_weights = True)

history=model.fit(x_train, y_train, batch_size=64, epochs=50, validation_data=(x_test, y_test), callbacks=[rlrp,earlystopping])
# Out:
# Epoch 1/50
# 1065/1065 [==============================] - 20s 16ms/step - loss: 1.3565 - accuracy: 0.5179 - val_loss: 1.2844 - val_accuracy: 0.5221 - lr: 0.0010
# Epoch 2/50
# 1065/1065 [==============================] - 16s 15ms/step - loss: 0.9808 - accuracy: 0.6404 - val_loss: 0.9482 - val_accuracy: 0.6499 - lr: 0.0010
# Epoch 3/50
# 1065/1065 [==============================] - 16s 15ms/step - loss: 0.7663 - accuracy: 0.7218 - val_loss: 0.8610 - val_accuracy: 0.6918 - lr: 0.0010
# Epoch 4/50
# 1065/1065 [==============================] - 17s 16ms/step - loss: 0.5903 - accuracy: 0.7885 - val_loss: 0.7020 - val_accuracy: 0.7505 - lr: 0.0010
# Epoch 5/50
# 1065/1065 [==============================] - 16s 15ms/step - loss: 0.4584 - accuracy: 0.8372 - val_loss: 0.6958 - val_accuracy: 0.7685 - lr: 0.0010
# Epoch 6/50
# 1065/1065 [==============================] - 16s 15ms/step - loss: 0.3640 - accuracy: 0.8713 - val_loss: 0.5554 - val_accuracy: 0.8150 - lr: 0.0010
# Epoch 7/50
# 1065/1065 [==============================] - 17s 16ms/step - loss: 0.2965 - accuracy: 0.8959 - val_loss: 0.5546 - val_accuracy: 0.8260 - lr: 0.0010
# Epoch 8/50
# 1065/1065 [==============================] - 16s 15ms/step - loss: 0.2479 - accuracy: 0.9135 - val_loss: 0.5665 - val_accuracy: 0.8289 - lr: 0.0010
# Epoch 9/50
# 1065/1065 [==============================] - 16s 15ms/step - loss: 0.2121 - accuracy: 0.9266 - val_loss: 0.4850 - val_accuracy: 0.8584 - lr: 0.0010
# Epoch 10/50
# 1065/1065 [==============================] - 16s 15ms/step - loss: 0.1851 - accuracy: 0.9356 - val_loss: 0.5133 - val_accuracy: 0.8531 - lr: 0.0010
# Epoch 11/50
# 1065/1065 [==============================] - 16s 15ms/step - loss: 0.1653 - accuracy: 0.9432 - val_loss: 0.5493 - val_accuracy: 0.8477 - lr: 0.0010
# Epoch 12/50
# 1065/1065 [==============================] - 16s 15ms/step - loss: 0.1443 - accuracy: 0.9501 - val_loss: 0.4593 - val_accuracy: 0.8726 - lr: 0.0010
# Epoch 13/50
# 1065/1065 [==============================] - 16s 15ms/step - loss: 0.1276 - accuracy: 0.9555 - val_loss: 0.4913 - val_accuracy: 0.8693 - lr: 0.0010
# Epoch 14/50
# 1065/1065 [==============================] - 18s 17ms/step - loss: 0.1184 - accuracy: 0.9582 - val_loss: 0.4731 - val_accuracy: 0.8861 - lr: 0.0010
# Epoch 15/50
# 1065/1065 [==============================] - 16s 15ms/step - loss: 0.1069 - accuracy: 0.9633 - val_loss: 0.5058 - val_accuracy: 0.8818 - lr: 0.0010
# Epoch 16/50
# 1065/1065 [==============================] - 16s 15ms/step - loss: 0.0965 - accuracy: 0.9671 - val_loss: 0.4735 - val_accuracy: 0.8822 - lr: 0.0010
# Epoch 17/50
# 1065/1065 [==============================] - 16s 15ms/step - loss: 0.0909 - accuracy: 0.9690 - val_loss: 0.4373 - val_accuracy: 0.8888 - lr: 0.0010
# Epoch 18/50
# 1065/1065 [==============================] - 18s 17ms/step - loss: 0.0871 - accuracy: 0.9702 - val_loss: 0.4952 - val_accuracy: 0.8895 - lr: 0.0010
# Epoch 19/50
# 1065/1065 [==============================] - 16s 15ms/step - loss: 0.0799 - accuracy: 0.9729 - val_loss: 0.5282 - val_accuracy: 0.8848 - lr: 0.0010
# Epoch 20/50
# 1065/1065 [==============================] - 16s 15ms/step - loss: 0.0746 - accuracy: 0.9746 - val_loss: 0.4470 - val_accuracy: 0.8983 - lr: 0.0010
# Epoch 21/50
# 1065/1065 [==============================] - 18s 17ms/step - loss: 0.0733 - accuracy: 0.9756 - val_loss: 0.4965 - val_accuracy: 0.8963 - lr: 0.0010
# Epoch 22/50
# 1065/1065 [==============================] - 16s 15ms/step - loss: 0.0654 - accuracy: 0.9779 - val_loss: 0.4303 - val_accuracy: 0.8978 - lr: 0.0010
# Epoch 23/50
# 1064/1065 [============================>.] - ETA: 0s - loss: 0.0631 - accuracy: 0.9790
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 1065/1065 [==============================] - 16s 15ms/step - loss: 0.0634 - accuracy: 0.9789 - val_loss: 0.4725 - val_accuracy: 0.8939 - lr: 0.0010
# Epoch 24/50
# 1065/1065 [==============================] - 17s 16ms/step - loss: 0.0238 - accuracy: 0.9922 - val_loss: 0.4121 - val_accuracy: 0.9150 - lr: 5.0000e-04
# Epoch 25/50
#  946/1065 [=========================>....] - ETA: 1s - loss: 0.0118 - accuracy: 0.9963

# %%
print("Accuracy of our model on test data : " , round(model.evaluate(x_test,y_test)[1]*100,2) , "%")

epochs = [i for i in range(25)]
fig , ax = plt.subplots(1,2)
train_acc = history.history['accuracy']
train_loss = history.history['loss']
test_acc = history.history['val_accuracy']
test_loss = history.history['val_loss']

fig.set_size_inches(20,6)
ax[0].plot(epochs , train_loss , label = 'Training Loss')
ax[0].plot(epochs , test_loss , label = 'Testing Loss')
ax[0].set_title('Training & Testing Loss')
ax[0].legend()
ax[0].set_xlabel("Epochs")

ax[1].plot(epochs , train_acc , label = 'Training Accuracy')
ax[1].plot(epochs , test_acc , label = 'Testing Accuracy')
ax[1].set_title('Training & Testing Accuracy')
ax[1].legend()
ax[1].set_xlabel("Epochs")
plt.show()
# Out:
# 533/533 [==============================] - 2s 4ms/step - loss: 0.4276 - accuracy: 0.9277
# Accuracy of our model on test data :  92.77 %
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-64-5904a47fb93b> in <cell line: 11>()
#       9
#      10 fig.set_size_inches(20,6)
# ---> 11 ax[0].plot(epochs , train_loss , label = 'Training Loss')
#      12 ax[0].plot(epochs , test_loss , label = 'Testing Loss')
#      13 ax[0].set_title('Training & Testing Loss')
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1686         """
#    1687         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1688         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1689         for line in lines:
#    1690             self.add_line(line)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     309                 this += args[0],
#     310                 args = args[1:]
# --> 311             yield from self._plot_args(
#     312                 this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#     313
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     502
#     503         if x.shape[0] != y.shape[0]:
# --> 504             raise ValueError(f"x and y must have same first dimension, but "
#     505                              f"have shapes {x.shape} and {y.shape}")
#     506         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (25,) and (50,)

# %%
model = Sequential()
model.add(layers.Conv1D(512, kernel_size=5, strides=1,
                        padding="same", activation="relu",
                        input_shape=(x_train.shape[1], 1)))
model.add(layers.BatchNormalization())
model.add(layers.MaxPool1D(pool_size=5, strides=2, padding="same"))

model.add(layers.Conv1D(512, kernel_size=5, strides=1,
                        padding="same", activation="relu"))
model.add(layers.BatchNormalization())
model.add(layers.MaxPool1D(pool_size=5, strides=2, padding="same"))

model.add(layers.Conv1D(256, kernel_size=5, strides=1,
                        padding="same", activation="relu"))
model.add(layers.BatchNormalization())
model.add(layers.MaxPool1D(pool_size=5, strides=2, padding="same"))

model.add(layers.Conv1D(256, kernel_size=3, strides=1, padding='same', activation='relu'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling1D(pool_size=5, strides = 2, padding = 'same'))

model.add(layers.Conv1D(128, kernel_size=3, strides=1, padding='same', activation='relu'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling1D(pool_size=3, strides = 2, padding = 'same'))

model.add(layers.Flatten())
model.add(layers.Dense(512, activation='relu'))
model.add(layers.BatchNormalization())
model.add(layers.Dense(14, activation="softmax"))


model.compile(optimizer = 'RMSprop' , loss = 'categorical_crossentropy' , metrics = ['accuracy'])

model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_27 (Conv1D)          (None, 58, 512)           3072
#
#  batch_normalization_36 (Ba  (None, 58, 512)           2048
#  tchNormalization)
#
#  max_pooling1d_27 (MaxPooli  (None, 29, 512)           0
#  ng1D)
#
#  conv1d_28 (Conv1D)          (None, 29, 512)           1311232
#
#  batch_normalization_37 (Ba  (None, 29, 512)           2048
#  tchNormalization)
#
#  max_pooling1d_28 (MaxPooli  (None, 15, 512)           0
#  ng1D)
#
#  conv1d_29 (Conv1D)          (None, 15, 256)           655616
#
#  batch_normalization_38 (Ba  (None, 15, 256)           1024
#  tchNormalization)
#
#  max_pooling1d_29 (MaxPooli  (None, 8, 256)            0
#  ng1D)
#
#  conv1d_30 (Conv1D)          (None, 8, 256)            196864
#
#  batch_normalization_39 (Ba  (None, 8, 256)            1024
#  tchNormalization)
#
#  max_pooling1d_30 (MaxPooli  (None, 4, 256)            0
#  ng1D)
#
#  conv1d_31 (Conv1D)          (None, 4, 128)            98432
#
#  batch_normalization_40 (Ba  (None, 4, 128)            512
#  tchNormalization)
#
#  max_pooling1d_31 (MaxPooli  (None, 2, 128)            0
#  ng1D)
#
#  flatten_9 (Flatten)         (None, 256)               0
#
#  dense_18 (Dense)            (None, 512)               131584
#
#  batch_normalization_41 (Ba  (None, 512)               2048
#  tchNormalization)
#
#  dense_19 (Dense)            (None, 14)                7182
#
# =================================================================
# Total params: 2412686 (9.20 MB)
# Trainable params: 2408334 (9.19 MB)
# Non-trainable params: 4352 (17.00 KB)
# _________________________________________________________________

# %%
rlrp = ReduceLROnPlateau(monitor='val_accuracy',
                                            patience=3,
                                            verbose=1,
                                            factor=0.5,
                                            min_lr=0.00001)
[==============================] - ETA: 0s - loss: 0.0097 - accuracy: 0.9969
# Epoch 33: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 1065/1065 [==============================] - 17s 16ms/step - loss: 0.0097 - accuracy: 0.9969 - val_loss: 0.5438 - val_accuracy: 0.9160 - lr: 5.0000e-04
# Epoch 34/50
# 1065/1065 [==============================] - 18s 17ms/step - loss: 0.0044 - accuracy: 0.9986 - val_loss: 0.4935 - val_accuracy: 0.9201 - lr: 2.5000e-04
# Epoch 35/50
# 1065/1065 [==============================] - 17s 16ms/step - loss: 0.0026 - accuracy: 0.9990 - val_loss: 0.5051 - val_accuracy: 0.9201 - lr: 2.5000e-04
# Epoch 36/50
# 1065/1065 [==============================] - 17s 16ms/step - loss: 0.0023 - accuracy: 0.9992 - val_loss: 0.5030 - val_accuracy: 0.9193 - lr: 2.5000e-04
# Epoch 37/50
# 1065/1065 [==============================] - 17s 16ms/step - loss: 0.0016 - accuracy: 0.9994 - val_loss: 0.5109 - val_accuracy: 0.9202 - lr: 2.5000e-04
# Epoch 38/50
# 1065/1065 [==============================] - 17s 16ms/step - loss: 0.0017 - accuracy: 0.9994 - val_loss: 0.5091 - val_accuracy: 0.9211 - lr: 2.5000e-04
# Epoch 39/50
# 1065/1065 [==============================] - 17s 16ms/step - loss: 0.0015 - accuracy: 0.9995 - val_loss: 0.5196 - val_accuracy: 0.9217 - lr: 2.5000e-04
# Epoch 40/50
# 1065/1065 [==============================] - 18s 17ms/step - loss: 0.0016 - accuracy: 0.9994 - val_loss: 0.5303 - val_accuracy: 0.9209 - lr: 2.5000e-04
# Epoch 41/50
# 1065/1065 [==============================] - 17s 16ms/step - loss: 0.0011 - accuracy: 0.9996 - val_loss: 0.5277 - val_accuracy: 0.9235 - lr: 2.5000e-04
# Epoch 42/50
# 1065/1065 [==============================] - 18s 17ms/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.5337 - val_accuracy: 0.9219 - lr: 2.5000e-04
# Epoch 43/50
# 1065/1065 [==============================] - 17s 16ms/step - loss: 0.0013 - accuracy: 0.9995 - val_loss: 0.5401 - val_accuracy: 0.9218 - lr: 2.5000e-04
# Epoch 44/50
# 1063/1065 [============================>.] - ETA: 0s - loss: 0.0012 - accuracy: 0.9996
# Epoch 44: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 1065/1065 [==============================] - 17s 16ms/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.5331 - val_accuracy: 0.9219 - lr: 2.5000e-04
# Epoch 45/50
# 1065/1065 [==============================] - 19s 18ms/step - loss: 9.0891e-04 - accuracy: 0.9997 - val_loss: 0.5337 - val_accuracy: 0.9222 - lr: 1.2500e-04
# Epoch 46/50
# 1065/1065 [==============================] - 17s 16ms/step - loss: 8.7457e-04 - accuracy: 0.9997 - val_loss: 0.5315 - val_accuracy: 0.9222 - lr: 1.2500e-04

# %%
print("Accuracy of our model on test data : " , round(model.evaluate(x_test,y_test)[1]*100,2) , "%")

epochs = [i for i in range(46)]
fig , ax = plt.subplots(1,2)
train_acc = history.history['accuracy']
train_loss = history.history['loss']
test_acc = history.history['val_accuracy']
test_loss = history.history['val_loss']

fig.set_size_inches(20,6)
ax[0].plot(epochs , train_loss , label = 'Training Loss')
ax[0].plot(epochs , test_loss , label = 'Testing Loss')
ax[0].set_title('Training & Testing Loss')
ax[0].legend()
ax[0].set_xlabel("Epochs")

ax[1].plot(epochs , train_acc , label = 'Training Accuracy')
ax[1].plot(epochs , test_acc , label = 'Testing Accuracy')
ax[1].set_title('Training & Testing Accuracy')
ax[1].legend()
ax[1].set_xlabel("Epochs")
plt.show()
# Out:
# 533/533 [==============================] - 2s 4ms/step - loss: 0.5277 - accuracy: 0.9235
# Accuracy of our model on test data :  92.35 %
